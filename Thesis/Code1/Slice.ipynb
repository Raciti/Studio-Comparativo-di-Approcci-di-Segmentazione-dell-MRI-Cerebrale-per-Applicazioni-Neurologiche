# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import nibabel as nib
import matplotlib.pyplot as plt
from pathlib import Path
ninImage = Path('/content/drive/MyDrive/Colab_Notebooks/Tesi/Images/Image_NiFTY/I1221051/I1221051.nii.gz')

nifti_path = str(ninImage)
nifti_image = nib.load(nifti_path)

data = nifti_image.get_fdata()

fig, axes = plt.subplots(1, 3, figsize=(15, 5))

plt.suptitle(f"SCAN {dir.name}", fontsize=25)

axes[0].imshow(data[:, :, data.shape[2] // 2], cmap='gray')
axes[0].set_title('Axial', fontsize=20)

axes[1].imshow(data[:, data.shape[1] // 2, :], cmap='gray')
axes[1].set_title('Coronal', fontsize=20)

axes[2].imshow(data[data.shape[0] // 2, :, :], cmap='gray')
axes[2].set_title('Sagittal', fontsize=20)

plt.show()

# %%
print( data.shape[2])
print( data.shape[2] // 2)
# Out:
# 256
# 128

# %%
plt.imshow(data[:, :, 50 ], cmap='gray')
plt.show()

# %%
import matplotlib.pyplot as plt

def create_subplot(rows, cols):
    fig, axes = plt.subplots(rows, cols, figsize=(cols*3, rows*3))
    return fig, axes

# Esempio di utilizzo
rows = 25
cols = 10
fig, axes = create_subplot(rows, cols)
z = 0
# Aggiungi le tue immagini ai subplot
for i in range(rows):
    for j in range(cols):
        # Supponiamo che "image_data" sia il tensore dell'immagine da visualizzare
        # Puoi sostituire "image_data" con i tuoi dati o immagini
        axes[i, j].imshow(data[:, :, z], cmap='gray')
        z += 1
        axes[i, j].axis('off')

plt.tight_layout()  # Ottimizza gli spazi tra i subplot
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
images = []
for i in range(255):
  images.append(data[:, :, i])

# %%
plt.imshow(images[3], cmap='gray')
plt.show()

# %%
rows = 25
cols = 10
fig, axes = create_subplot(rows, cols)
z = 0
for i in range(rows):
    for j in range(cols):
        # Supponiamo che "image_data" sia il tensore dell'immagine da visualizzare
        # Puoi sostituire "image_data" con i tuoi dati o immagini
        axes[i, j].imshow(images[z], cmap='gray')
        z += 1
        axes[i, j].axis('off')

plt.tight_layout()  # Ottimizza gli spazi tra i subplot
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.
